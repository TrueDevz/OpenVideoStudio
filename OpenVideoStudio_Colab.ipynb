# %% [markdown]
# # OpenVideoStudio - Google Colab Setup 🚀
# Run this notebook to use OpenVideoStudio completely free in the cloud!

# %%
# 1. Clone the repository
# !git clone https://github.com/TrueDevz/OpenVideoStudio.git
# %cd OpenVideoStudio

# 2. Install dependencies
# !pip install fastapi uvicorn pydantic google-generativeai edge-tts requests moviepy openai-whisper

# Install FFmpeg (required for moviepy and whisper)
# !apt-get install -y ffmpeg

# Install localtunnel to expose the port
# !npm install -g localtunnel

# %%
import os
# 3. Set your API Keys (Free Tiers)
os.environ['GEMINI_API_KEY'] = 'YOUR_GEMINI_API_KEY'
os.environ['PEXELS_API_KEY'] = 'YOUR_PEXELS_API_KEY'

# %%
# 4. Run the Server and Expose URL
import urllib
print("Password/Enpoint IP for localtunnel:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# !uvicorn backend.main:app --host 0.0.0.0 --port 8000 & npx localtunnel --port 8000

# Click the URL generated by localtunnel (looks like https://loca.lt/...) and enter the IP shown above!
